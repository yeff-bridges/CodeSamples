# %%
import numpy as np
import FromScratchModule as fs
from matplotlib import pyplot as plt

# %%
x,y = fs.Toy.Clusters(1000,2,2,1.5)
plt.scatter(x[:,0],x[:,1],c=np.argmax(y,axis=1))

# %%
def dist(x1,x2):
    return np.sqrt(np.sum((x1.reshape(x1.shape[0],1,x1.shape[1]) - x2)**2,axis=2))

# %%
plt.hist(dist(x,x).flatten())
# Out:
# (array([4.65274e+05, 9.62074e+05, 8.95854e+05, 7.30826e+05, 5.44934e+05,
#         2.87016e+05, 9.42440e+04, 1.78540e+04, 1.85400e+03, 7.00000e+01]),
#  array([0.        , 0.98542074, 1.97084147, 2.95626221, 3.94168294,
#         4.92710368, 5.91252441, 6.89794515, 7.88336588, 8.86878662,
#         9.85420736]),
#  <a list of 10 Patch objects>)

# %%
r = 1
n = 300

# %%
dists = dist(x,x)
neighbors = (dists < r) * (dists > 0)
plt.scatter(x[:,0],x[:,1],c=np.sum(neighbors, axis=0) > n)

# %%
core_points = np.sum(neighbors, axis=0) > n

# %%
cores = {}
core_neighbors = np.tril(dist(x[core_points], x[core_points]) < r, k=-1) 
for point in core_neighbors[1:]:
    new_core = True
    for core in cores.:
        if point in core:
            new_core = False
            break
        if new_core:
            core_
    for neighbor in point[point]:
# Out:
# array([[False, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
for point in core_neighbors
